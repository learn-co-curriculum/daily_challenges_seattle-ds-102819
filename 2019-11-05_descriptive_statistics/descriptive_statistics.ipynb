# %% [markdown]
# # Exploring Statistical Data

# %% [markdown]
# In this challenge, we will be using the FIFA19 dataset, `'../data/fifa.csv'`, again.  Read in the csv and create a dataframe.

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
# code here to read in `fifa.csv` and assign a dataframe to the variable `df`
df = pd.read_csv('../data/fifa.csv')

# %% [markdown]
# **1) What are the mean age and the median age for the players in this dataset?**
#
# The column is named 'Age'

# %%
# code here
df['Age'].mean()
df['Age'].median()
# Out:
# 25.0

# %% [markdown]
# In your own words, how are the mean and median related to each other and what do these values tell us aboutthe distribution of the players' ages?

# %%
mean is average number and median is the middle of all the numbers

# %% [markdown]
# **2) Who is the oldest player in Argentina and how old is he?**

# %%
# code here
Argentina_players = df[df['Nationality'] == 'Argentina']
Argentina_players
# Out:
#        Unnamed: 0      ID            Name  Age  \
# 0               0  158023        L. Messi   31
# 15             15  211110       P. Dybala   24
# 23             23  153079       S. Agüero   30
# 38             38  167664      G. Higuaín   30
# 43             43  201399       M. Icardi   25
# ...           ...     ...             ...  ...
# 19142        9142  240955        T. Durso   19
# 19148        9148  237125      V. Barbero   17
# 19431        9431  236431      E. Alarcón   25
# 19654        9654  245726   F. Bustamante   19
# 19780        9780  241099  L. Finochietto   21
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 15     https://cdn.sofifa.org/players/4/19/211110.png   Argentina
# 23     https://cdn.sofifa.org/players/4/19/153079.png   Argentina
# 38     https://cdn.sofifa.org/players/4/19/167664.png   Argentina
# ...

# %%
Argentina_players['Age'].max()
# Out:
# 41
