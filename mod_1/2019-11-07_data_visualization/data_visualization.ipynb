# %% [markdown]
# # Data Visualization

# %% [markdown]
# In this challenge, we will be using the FIFA19 dataset, `'../data/fifa.csv'`, again.  Read in the csv and create a dataframe.

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
# code here to read in `fifa.csv` and assign a dataframe to the variable `df`
df = pd.read_csv("../data/fifa.csv")

# %% [markdown]
# Continuing to use the same FIFA dataset, plot data using whichever plotting library you are most comfortable with.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# **1) Find the top 10 countries with the most players (using the 'Nationality' column). Create a bar chart showing the number of players in those 10 countries**
#
# Don't forget to add a **title** and **x axis label** to your charts.
#
# If you are unable to find the top 10 countries but want the chance to demonstrate your plotting skills use the following dummy data to create a bar chart
# ```
# Country Name  | Num Players
# ============  | ===========
# Country A     | 100
# Country B     | 60
# Country C     | 125
# Country D     | 89
# ```

# %%
# code here to get the top 10 countries with the most players
top_ten = df.groupby('Nationality').count().sort_values('Name', ascending = False)[0:10]
top_ten
# Out:
#              Unnamed: 0    ID  Name   Age  Photo  Flag  Overall  Potential  \
# Nationality
# England            1823  1823  1823  1823   1823  1823     1823       1823
# Germany            1318  1318  1318  1318   1318  1318     1318       1318
# Spain              1173  1173  1173  1173   1173  1173     1173       1173
# Argentina          1022  1022  1022  1022   1022  1022     1022       1022
# France              977   977   977   977    977   977      977        977
# Brazil              897   897   897   897    897   897      897        897
# Italy               780   780   780   780    780   780      780        780
# Colombia            687   687   687   687    687   687      687        687
# Japan               531   531   531   531    531   531      531        531
# Netherlands         526   526   526   526    526   526      526        526
#
#              Club  Club Logo       ...        Composure  Marking  \
# Nationality                        ...
# England      1823       1823       ...             1818     1818
# Germany      1318       1318       ...             1315     1315
# Spain        1173       1173       ...             1172     1172
# Argentina    1021       1022       ...             1021     1021
# France        977        977       ...              974      974
# Brazil        897        897       ...              895      895
# Italy         780        780       ...              777      777
# Colombia      687        687       ...              685      685
# Japan         531        531       ...              531      531
# Netherlands   526        526       ...              525      525
#
#              StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# Nationality
# England                1818           1818      1818        1818       1818
# Germany                1315           1315      1315        1315       1315
# Spain                  1172           1172      1172        1172       1172
# Argentina              1021           1021      1021        1021       1021
# France                  974            974       974         974        974
# Brazil                  895            895       895         895        895
# Italy                   777            777       777         777        777
# Colombia                685            685       685         685        685
# Japan                   531            531       531         531        531
# Netherlands             525            525       525         525        525
#
#              GKPositioning  GKReflexes  Release Clause
# Nationality
# England               1818        1818            1618
# Germany               1315        1315            1266
# Spain                 1172        1172            1064
# Argentina             1021        1021             898
# France                 974         974             912
# Brazil                 895         895             857
# Italy                  777         777             648
# Colombia               685         685             632
# Japan                  531         531             504
# Netherlands            525         525             492
#
# [10 rows x 88 columns]

# %%
# code here to plot a bar chart
fig, ax = plt.subplots(figsize=(10, 6))

ax = sns.barplot(x = top_ten.index,
                 y = top_ten['Name'],
                 ax = ax)
plt.ylabel('Number of Players')
plt.title('Top Ten Countries with the Most Number of Soccer Players');

# %% [markdown]
# **2) Below is a scatter plot for the player stats `StandingTackle` and `SlidingTackle`**

# %%
plt.scatter(df['StandingTackle'], df['SlidingTackle'])
plt.title('Standing Tackle vs. Sliding Tackle')
plt.xlabel('Standing Tackle')
plt.ylabel('Sliding Tackle')
plt.show()

# %% [markdown]
# How would you describe the relationship between these two features?

# %%
"""
There is a strong positive, linear relationship between 'Standing Tackle' and 'Sliding Tackle,' meaning that
given a player's standing tackle stat, they are expected to have a proportional sliding tackle stat. In this case, 
it appears that the proportion is 1:1, so the two stats are approximately equal.
"""
